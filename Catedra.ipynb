# %% [markdown]
# <a href="https://colab.research.google.com/github/Jpdelaf/Apuntes_WEB/blob/main/Catedra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Catedra**
#
# La motivacion del curso es el impacto de las aplicaciones web, ejemplo facebook prediciendo ciertas cosas de las personas por lo cercanas que son a nosotros.
#
# el ramo tiene una clase de etica a diferencia de las otras secciones

# %% [markdown]
# ## **CLASE 1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   **Fundamentos de la web:**
#
# Ver definiciones importantes relacionadas con internet, protocolos y sobre HTML, CSS y JavaScript (investigar TypeScript).
#
# 2.  **Desarrollo de una app web:**
#
# Se usaran herramientas como React, Node y Express. Tambien CSS Avanzado y construccion de APIs.
# Desarrollo tanto de Cliente como de Servidor.
#
#
# 3.   **Gestion de datos:**
#
# Manejo de Cookies, sesiones y datos en el navegador.
# como habilitar opciones avanzadas de manera segura (Ciberseguridad).
#
# 4.   **Software + Web:**
#
# Uso de elementos para expandir y mejorar la experiencia de desarrollo como CI, CD, Testing y otras practicas.
# Funcionalidades modernas por medio de buenas practicas.
#
# 5.   **Seguridad + Web:**
#
# Conocer fundamentos de ciberseguridad y privacidad.
# ¿NGINX? ¿ReverseProxxy?
#
# 6.   **El mundo real:**
#
# Etica y produccion de aplicaciones.
# Se necesitan soluciones reales y utiles que generen valor.

# %% [markdown]
# La evaluacion es a traves de:
#
#
# *   **Actividades:**
#
# Incentivar el uso de un nuevo elemento. hay 6 actividades.
#
# *   **Tareas:**
#
# Evaluar aprendizages principales, es t1 + t2 + Actividades / 3
#
# *   **Controles:**
#
# son 5 se borra el peor.
#
# *   **Proyecto:**
#
# 4 entregas van haciendose mas pesadas, la ultima es reprobatoria.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Primero se hacen tareas individuales y luego es el proyecto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **CLASE 2**

# %% [markdown]
# Fundamentos de la web:
# - Ver que hay entre el url y el servidor
